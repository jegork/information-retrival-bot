# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments, Trainer, default_data_collator
from datasets import Dataset
import pandas as pd
import pickle
import torch

# %%
with open('twitter_data.pickle', 'rb') as f:
    twitter_data = pickle.loads(f.read())
    
twitter_df = pd.DataFrame.from_records(twitter_data, columns=['response', 'context-0', 'context-1', 'context-2']).sample(frac=1)
twitter_df.head(10)
# Out:
#                                                  response  \
# 208749  Come on fix your connection with Carphone Ware...
# 59983   I’d hate to be a later flight because my 8:40 ...
# 132046  Flying with you on Thu to bring supplies to #P...
# 123377  -  just spent 30 min with tech support. No sol...
# 78931   Explain to me how the 3G is faster than the LT...
# 93895   Is it true that some game downloads require an...
# 72362            Thanks for cancelling my train CRAAAAP!!
# 116969  hi my mac pro won't read my sd card pls send help
# 163657  Your service is dogshit it makes me want to bu...
# 11028   is there not an easy way to get all my actions...
#
#                                                 context-0  \
# 208749  🤔 We'd like to help Claire, are you trying to ...
# 59983   They’re the worst. Last time I traveled on a h...
# 132046  Hello. Sorry for the delay. Are you still need...
# 123377  Hello Mike, is there anything I can assist you...
# 78931   Hi there! I would be happy to assist you with ...
# 93895   Hi there! If you are seeing download issues be...
# 72362                  Sorry for that, which service? ^PA
# 116969  Hi there. We'd like to help. Are you using a b...
# 163657  Good evening Jake! I would really like to help...
# 11028   Hi there, You may use the preset manager in Ph...
#
#                                                 context-1  \
# 208749  I called them today and on Saturday and they s...
# 59983   Made it! An hour and a half after I was suppos...
# 132046                       I do - thanks for assisting.
# 123377  I cannot get access to My Account . When I typ...
# 78931   My bad just redid the test it's including the ...
# 93895   It's not about slow downloads.  The downloads ...
# 72362                                   19:15 to Preston!
# 116969  I'm using my Mac's built-in reader. Other lapt...
# 163657                                           too late
# 11028   I will try that again but when I open the pres...
#
#                                                 context-2
# 208749  🤔 We're not currently aware of any issues, Cla...
# 59983      Great news. Enjoy your pre-Thanksgiving lunch!
# 132046  When traveling Thursday, you can speak with ou...
# 123377      Have you tested an alternate web browser? ^JH
# 78931   Thank you. Can you please send me a DM. I want...
# 93895   Gotcha. Are you seeing a specific error code/m...
# 72362                                     From where? ^PA
# 116969  OK. Let's try removing the SD Card and restart...
# 163657  I see, please let us know if you reconsider. H...
# 11028   You would need to export presets, please check...

# %%
with open('ubuntu_data.pickle', 'rb') as f:
    ubuntu_data = pickle.loads(f.read())
    
ubuntu_df = pd.DataFrame.from_records(ubuntu_data, columns=['response', 'context-0', 'context-1', 'context-2']).sample(frac=1)
ubuntu_df.head(10)
# Out:
#                                                 response  \
# 11543                                      lol ok hehehe
# 19202           you can convert it using mysql, I think.
# 16208                  nothing i know of, but i'll check
# 15471                           which one is he getting?
# 5175   hi all, can i tell to my ubuntu, 'when you loc...
# 7244                    You have to put 'ldap ssl = off'
# 10216  That is correct.  Let me come up with a test o...
# 9390                                You just said 660...
# 14895        do you know if direct rendering is enabled?
# 21801                     so dmesg | grep 'system panic'
#
#                                                context-0  \
# 11543         like a sidewalk step, you gotta be careful
# 19202                                               how?
# 16208  it could be a lack of memory thats causing jer...
# 15471  well, i hadn't got that far yet..lol, i just t...
# 5175                            on a laptop or a desktop
# 7244   in /etc/ldap/ldap.conf or /etc/smbldap/smbldap...
# 10216  odd.  what do you have after the command.  is ...
# 9390   well i didn't know how to convert that to numbers
# 14895        not off the top of my head. how do i check?
# 21801                                 dmesg | grep panic
#
#                                                context-1  \
# 11543  .. yeah.. it is probably because im real tired...
# 19202  try this.  http://sourceforge.net/projects/mdb...
# 16208  i have actually added one gig my average cpu u...
# 15471                damn which sound card should i get?
# 5175                                                how?
# 7244                              in /etc/samba/smb.conf
# 10216                                              {} \;
# 9390   But okay, hm, then this is strange, is there a...
# 14895                       glxinfo | grep 'direct' iirc
# 21801                                                !hi
#
#                                                context-2
# 11543  I have done many an all nighter on Linux, but ...
# 19202                                           thanks!!
# 16208  well if you've recently upgraded skype and fir...
# 15471  look at the last post, it looks like he chose ...
# 5175   xset dpms force off are you intending to write...
# 7244   thx. still doesn't work though. Now it says 'C...
# 10216   hmm does the function exit with a 0 exit status?
# 9390                      what's ACL? it's not installed
# 14895                 ya its on.  i have xinemera on too
# 21801                i did chown the dmesg i got nothing

# %%
comb_df = pd.concat([twitter_df[:50000], ubuntu_df[:20000]], ignore_index=True)\
    .sample(frac=1).reset_index(drop=True)
comb_df.head(10)
# Out:
#                                             response  \
# 0  VERY Disappointing cotton bed sheets as they g...
# 1  issue with order id-403-9859026-0246720.. Cust...
# 2  Dear #BlueBird color me disappointed &amp; dis...
# 3  Hey all of my Roku devices get this error seve...
# 4  Dear  Why, oh, can’t eye type the letter eye? ...
# 5  Can't ever win with these people why is my log...
# 6                      my route table looks fine :-\
# 7       ok how do I check this when i boot into xfce
# 8  your Prime deliveries have turned to 2/3 day d...
# 9  What's the command line for that? (Just for th...
#
#                                            context-0  \
# 0  Sorry Mathew, can you tell me the barcode numb...
# 1  I’m sorry about the hassle. Please drop in you...
# 2  Hi Donna. I'm sorry to hear that. Is there som...
# 3  Sorry, Travis! Still need help? If so, try: ht...
# 4  We'd love to assist you. Let's go to Settings&...
# 5  My apologies, as I am trying to see if anythin...
# 6  post to pastebin output from 'ifconfig ; route...
# 7  open a terminal and make sure xfce4-panel is r...
# 8  I'm sorry for the trouble! We don't want to le...
# 9  sudo apt-get install pastebinit then cat /etc/...
#
#                                            context-1  \
# 0  im sorry i do not have the barcode to hand but...
# 1  order id-403-9859026-0246720.. I called many t...
# 2  Hi Beth. I have the Blue Bird card and I can't...
# 3  Already performed these troubleshooting tasks....
# 4  I'm a dumby - thanks for the quick response! A...
# 5                                 Not working for me
# 6                      http://pastebin.com/d543c048d
# 7  understood but what would the command in the t...
# 8  You have indeed. Next day delivery has let me ...
# 9  It is now 1792x1344, and I wan't it to be 1024...
#
#                                            context-2
# 0  That's not a problem Mathew. Do you still have...
# 1  We cannot check your order details on social p...
# 2  up to 30 calendar days for car rentals.If we c...
# 3  Sorry--we're looking into this error. Please c...
# 4  You're welcome.  Were you able to see what ver...
# 5  I would be happy to look into this further for...
# 6  'Chain INPUT (policy DROP...' - you didn't do ...
# 7                          ps aux | grep xfce4-panel
# 8  I'm very sorry to hear you still haven't recei...
# 9                   how did you install the drivers?

# %%
test_df = pd.concat([twitter_df[50000:52000], ubuntu_df[20000:21000]], ignore_index=True).reset_index(drop=True)
test_df.head(5)
# Out:
#                                             response  \
# 0  any problem with cleardb in west europe ? our ...
# 1  these updates are making iOS behave like andro...
# 2  how in the world are you guys not available 24...
# 3  can you tell us where th spare seats are? 10:4...
# 4                            Breh fix this WiFi shit
#
#                                            context-0  \
# 0  error log was enabled, I just disabled it, we'...
# 1  We'd like to help with this. Send us a DM with...
# 2  Hello, Jeremy. I’m sorry we weren’t here when ...
# 3  Morning, unreserved seating is available in ca...
# 4           what’s wrong? cause my shit been trippin
#
#                                            context-1  \
# 0  can you raise a request through https://t.co/Z...
# 1  I guess this is required if not do let me know...
# 2  Your support is completely unavailable. I can'...
# 3  Will it be announced on the tannoy? There's a ...
# 4  My shit will just stop working and I keep havi...
#
#                                            context-2
# 0                 ok I just created a ticket, thanks
# 1  One more reference I don’t know what’s this go...
# 2  We apologize for your experience. Let me know ...
# 3  1/2 Depending on how many of the unreserved se...
# 4  We'd like to help with this Wi-Fi issue. Can y...

# %%
dataset = Dataset.from_pandas(comb_df)
dataset

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-medium")
model = AutoModelForCausalLM.from_pretrained("microsoft/DialoGPT-medium")
tokenizer.pad_token = tokenizer.eos_token

# %%
def preprocess_function(data):
    flatten = lambda l: [item for sublist in l for item in sublist]
    
    output = [tokenizer(d + tokenizer.eos_token, max_length=32, truncation=True, padding='max_length', return_tensors='pt')['input_ids'] for d in data.values()]
    output = flatten(list(reversed(output)))
    
    return {'input_ids': output, 'labels': output }

tokenized_data = dataset.map(preprocess_function, batched=False, remove_columns=dataset.column_names)
# Out:
#   0%|          | 0/70000 [00:00<?, ?ex/s]

# %%
batch_size = 16
args = TrainingArguments(
    "dialogpt-twitter-ubuntu-finetuned",
    learning_rate=2e-6,
    per_device_train_batch_size=batch_size,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=1,
    fp16=False,
    report_to="none",
    warmup_steps=1000,
)

trainer = Trainer(
    model,
    args,
    train_dataset=tokenized_data,
    data_collator=default_data_collator,
)

trainer.train()

# %%
trainer.save_model()

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-medium")
model = AutoModelForCausalLM.from_pretrained("jegorkitskerkin/dialogpt-twitter-ubuntu")

# %%
for step in range(5):
    # encode the new user input, add the eos_token and return a tensor in Pytorch
    new_user_input_ids = tokenizer.encode(input(">> User:") + tokenizer.eos_token, return_tensors='pt')

    # append the new user input tokens to the chat history
    #bot_input_ids = torch.cat([chat_history_ids, new_user_input_ids], dim=-1) if step > 0 else new_user_input_ids
    bot_input_ids = new_user_input_ids

    # generated a response while limiting the total chat history to 1000 tokens, 
    chat_history_ids = model.generate(
        bot_input_ids, max_length=1000, 
        pad_token_id=tokenizer.eos_token_id,
        min_length=16,
        num_return_sequences=1,
        no_repeat_ngram_size=2,
        do_sample=True,
        top_k=50,
        top_p=0.9,
        temperature = 0.6,
                                     )
    # pretty print last ouput tokens from bot
    print("DialoGPT: {}".format(tokenizer.decode(chat_history_ids[:, bot_input_ids.shape[-1]:][0], skip_special_tokens=True)))

# %%
test_emb = tokenizer('\n\n'.join(test_df['response'].tolist()), max_length=64, truncation=True, return_tensors='pt')

# %%
import torch
from tqdm import tqdm

model = model.cuda()

max_length = model.config.n_positions
stride = 64

nlls = []
for i in tqdm(range(0, test_emb.input_ids.size(1), stride)):
    begin_loc = max(i + stride - max_length, 0)
    end_loc = min(i + stride, test_emb.input_ids.size(1))
    trg_len = end_loc - i    # may be different from stride on last loop
    input_ids = test_emb.input_ids[:,begin_loc:end_loc].to('cuda')
    target_ids = input_ids.clone()
    target_ids[:,:-trg_len] = -100

    with torch.no_grad():
        outputs = model(input_ids, labels=target_ids)
        neg_log_likelihood = outputs[0] * trg_len

    nlls.append(neg_log_likelihood)

ppl = torch.exp(torch.stack(nlls).sum() / end_loc)
print('Perplexity', ppl.item())
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 26.73it/s]
# Perplexity 308.0859069824219
